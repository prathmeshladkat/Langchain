# %%
import os
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model= ChatGroq(model="Gemma2-9b-it", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(output_version=None, profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000025984C48D00>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000025984C493F0>, model_name='Gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)
