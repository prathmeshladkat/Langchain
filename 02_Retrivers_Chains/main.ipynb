# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
## langsmith Tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv('LANGCHAIN_API_KEY')
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000002663682B430> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002663682B1C0> root_client=<openai.OpenAI object at 0x0000026636829F00> root_async_client=<openai.AsyncOpenAI object at 0x000002663682BD00> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True

# %%
## input and get response from LLM

result = llm.invoke("what is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence systems designed to generate new content. This can include images, text, music, videos, and other media. Unlike traditional AI that might focus on classifying or analyzing data, generative AI models create new data that is similar to the data they were trained on. Popular types of generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These consist of two neural networks – a generator and a discriminator – that are trained together. The generator creates new data instances, while the discriminator evaluates them. The goal is for the generator to produce outputs indistinguishable from real data.\n\n2. **Variational Autoencoders (VAEs):** These models encode input into a lower-dimensional space and then decode it back to the original. They are often used for generating new data that resembles the training data.\n\n3. **Transformer-based Models:** Models like GPT (Generative Pre-trained Transformer) are used primarily for natural language processing tasks such as text generation, summarization, translation, and more.\n\nGenerative AI has numerous applications across various fields, including but not limited to:\n\n- **Creative industries:** Generating art, music, and writing.\n- **Entertainment:** Creating realistic CGI for movies and video games.\n- **Education:** Developing teaching materials, personalized learning content, and language translation.\n- **Healthcare:** Drug discovery and developing synthetic medical data for research.\n- **Business:** Automating content creation, generating product descriptions, and enhancing customer support with chatbots.\n\nGenerative AI models have garnered attention not only for their creative potential but also for raising questions about ethics, originality, copyright, and the authenticity of generated content.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 341, 'prompt_tokens': 13, 'total_tokens': 354, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9dd8023e2f', 'id': 'chatcmpl-DY4ZHijIDTDreDyoMOiG67hl10J65', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019dbe3b-c90d-79f0-a03b-ac94e99d83b7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 341, 'total_tokens': 354, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert ai Engineer. Provide me the answer based on questions"),
        ("user", "{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert ai Engineer. Provide me the answer based on questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm

result = chain.invoke({"input": "Can you tell me about langsmith?"})
print(result)
# Out:
# content='Langsmith is a product developed by LangChain, focused on providing developers with robust tools for building and managing applications that leverage language models. It is designed to enhance the development workflow by offering features that facilitate the evaluation, testing, and monitoring of language model-powered applications. Key aspects of Langsmith include tooling for feedback collection, performance tracking, and real-time debugging. These capabilities make it easier for developers to iterate on their projects and ensure that their language model implementations are both effective and reliable, ultimately helping to create more refined and user-centric AI applications.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 109, 'prompt_tokens': 33, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_6dd86a7be3', 'id': 'chatcmpl-DY4jfiZGl7H1qAXBrtJZ9Z3nA3BZT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019dbe45-9a42-7a90-8ea7-1e82dffebf86-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 109, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## string output parser

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain= prompt | llm | output_parser

result = chain.invoke({"input": "Can you tell me about langsmith?"})
print(result)
# Out:
# Langsmith is a tool designed to enhance the development, debugging, and monitoring of applications that utilize large language models (LLMs). It provides developers with the ability to test and optimize prompts and chains, track and visualize execution flows, evaluate outputs, and manage datasets effectively. This platform is essential for improving the reliability and performance of applications that rely on natural language processing capabilities, offering insights into model behavior and facilitating a better understanding of how language models interact with data. Langsmith aims to streamline the process of creating robust language-based applications by offering comprehensive tools for testing and analytics.
